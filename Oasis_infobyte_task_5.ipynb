# %%
import pandas as pd

# %%
df=pd.read_csv('advertising.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.lmplot(x='TV',y='Sales',data=df)

# %% [markdown]
# Price of tv is linear with Sales

# %%
sns.lmplot(x='Radio',y='Sales',data=df)

# %%
sns.lmplot(x='Newspaper',y='Sales',data=df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sns.distplot(df['Sales'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9424\4256165467.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'])
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(df['TV'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9424\2926773584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TV'])
# <Axes: xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['Newspaper'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9424\3262100579.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.distplot(df['Radio'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9424\2532850109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Radio'])
# <Axes: xlabel='Radio', ylabel='Density'>

# %% [markdown]
# There are no outliers in any of the column

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('Sales',axis=1),df['Sales'],test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9253958119443946

# %%
model.predict(x_test)
# Out:
# array([14.69591306,  8.11760377,  3.66454826, 12.29785933, 19.34369247,
#        14.88378558, 20.74166793,  7.58123338, 16.33357083,  3.5338886 ,
#         7.55421682, 11.83945296, 13.89787589, 14.15412185,  5.31090272,
#        17.26060108, 20.22926311, 13.29376461, 16.92529347, 18.56417018,
#        21.65750467, 17.21246638, 12.21042198, 10.34622649, 14.36082361,
#        19.61840877, 12.31837552, 18.78547685, 15.21827011,  8.35999147,
#         9.61464299, 24.08657529, 24.73000483, 16.43063452, 21.24916222,
#         9.0956804 , 12.34415604, 15.55651438, 19.91210543, 11.00166885])

# %%
x_test.head()
# Out:
#         TV  Radio  Newspaper
# 103  187.9   17.2       17.9
# 49    66.9   11.7       36.8
# 8      8.6    2.1        1.0
# 1     44.5   39.3       45.1
# 28   248.8   27.1       22.9

# %%
y_test.head()
# Out:
# 180    10.5
# 57     13.2
# 129     9.7
# 192     5.9
# 72      8.8
# Name: Sales, dtype: float64

# %%
df_final=x_test.copy()

# %%
df_final['y_real']=y_test

# %%
df_final['y_pred']=model.predict(x_test)

# %%
model.predict(x_test)
# Out:
# array([14.69591306,  8.11760377,  3.66454826, 12.29785933, 19.34369247,
#        14.88378558, 20.74166793,  7.58123338, 16.33357083,  3.5338886 ,
#         7.55421682, 11.83945296, 13.89787589, 14.15412185,  5.31090272,
#        17.26060108, 20.22926311, 13.29376461, 16.92529347, 18.56417018,
#        21.65750467, 17.21246638, 12.21042198, 10.34622649, 14.36082361,
#        19.61840877, 12.31837552, 18.78547685, 15.21827011,  8.35999147,
#         9.61464299, 24.08657529, 24.73000483, 16.43063452, 21.24916222,
#         9.0956804 , 12.34415604, 15.55651438, 19.91210543, 11.00166885])

# %%
df_final.head()
# Out:
#         TV  Radio  Newspaper  y_real     y_pred
# 103  187.9   17.2       17.9    14.7  14.695913
# 49    66.9   11.7       36.8     9.7   8.117604
# 8      8.6    2.1        1.0     4.8   3.664548
# 1     44.5   39.3       45.1    10.4  12.297859
# 28   248.8   27.1       22.9    18.9  19.343692

# %%
sns.lmplot(x='y_real',y='y_pred',data=df_final)

# %%
model.predict([[80.23,15.23,7.23]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.41140002])

# %% [markdown]
# Model accuracy is 92%
